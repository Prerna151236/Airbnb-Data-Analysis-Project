# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r"C:\Users\Dell\Downloads\airBNB\Australia\listings.csv")

# %%
df.head()
# Out:
#           id                           listing_url     scrape_id last_scraped  \
# 0  1051911.0  https://www.airbnb.com/rooms/1051911  2.030000e+13   03-03-2025
# 1  1100380.0  https://www.airbnb.com/rooms/1100380  2.030000e+13   03-03-2025
# 2  1125557.0  https://www.airbnb.com/rooms/1125557  2.030000e+13   03-03-2025
# 3  1130919.0  https://www.airbnb.com/rooms/1130919  2.030000e+13   03-03-2025
# 4    11156.0    https://www.airbnb.com/rooms/11156  2.030000e+13   03-03-2025
#
#         source                               name  \
# 0  city scrape           Tree Topz by Beach Stays
# 1  city scrape  Fabulous location, fabulous place
# 2  city scrape        LUXURY BEACHFRONT APARTMENT
# 3  city scrape                 Coogee Beach House
# 4  city scrape               An Oasis in the City
#
#                                          description  \
# 0  Treetopz is a secluded haven perched high abov...
# 1  Fresh and fun Hollywood Regency apartment in t...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   listing_url                                   18017 non-null  object
#  2   scrape_id                                     18017 non-null  float64
#  3   last_scraped                                  18017 non-null  object
#  4   source                                        18017 non-null  object
#  5   name                                          18017 non-null  object
#  6   description                                   17703 non-null  object
#  7   neighborhood_overview                         8410 non-null   object
#  8   picture_url                                   18017 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  1.801700e+04  1.801700e+04  1.801700e+04         18009.000000
# mean   7.119737e+17  2.030000e+13  2.027744e+08            30.734355
# std    5.337916e+17  0.000000e+00  2.019040e+08            97.041923
# min    1.115600e+04  2.030000e+13  3.558200e+04             0.000000
# 25%    4.223758e+07  2.030000e+13  2.719164e+07             1.000000
# 50%    9.010000e+17  2.030000e+13  1.231830e+08             3.000000
# 75%    1.190000e+18  2.030000e+13  3.426539e+08            23.000000
# max    1.370000e+18  2.030000e+13  6.818117e+08           863.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               18009.000000                           0.0  18017.000000
# mean                   45.629963                           NaN    -33.850777
# std                   122.539648                           NaN      0.089524
# ...

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df.isnull().sum()
(df.isnull().sum()/len(df))*100
# Out:
# id                                               0.000000
# listing_url                                      0.000000
# scrape_id                                        0.000000
# last_scraped                                     0.000000
# source                                           0.000000
#                                                   ...
# calculated_host_listings_count                   0.000000
# calculated_host_listings_count_entire_homes      0.000000
# calculated_host_listings_count_private_rooms     0.000000
# calculated_host_listings_count_shared_rooms      0.000000
# reviews_per_month                               16.839651
# Length: 79, dtype: float64

# %%
#Check Duplicate Columns
df.duplicated().sum()
# Out:
# 0

# %%
#Drop the Columns
df = df.drop(columns=[
    'scrape_id',
    'last_scraped',
    'listing_url',
    'picture_url',
    'host_url'
], errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   description                                   17703 non-null  object
#  4   neighborhood_overview                         8410 non-null   object
#  5   host_id                                       18017 non-null  int64
#  6   host_name                                     18009 non-null  object
#  7   host_since                                    18009 non-null  object
#  8   host_location                                 13300 non-null  object
# ...

# %%
#Clean the Price Column
df['price'] =df['price'].replace('[/$,]', '', regex=True)
df['price'] = df['price'].astype(float)
df['price'].head()
# Out:
# 0    657.0
# 1    210.0
# 2    157.0
# 3    950.0
# 4     65.0
# Name: price, dtype: float64

# %%
#Convert Data Type
df['host_since'] =pd.to_datetime(df['host_since'], errors='coerce')
df['last_review'] =pd.to_datetime(df['last_review'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   description                                   17703 non-null  object
#  4   neighborhood_overview                         8410 non-null   object
#  5   host_id                                       18017 non-null  int64
#  6   host_name                                     18009 non-null  object
#  7   host_since                                    6763 non-null   datetime64[ns]
#  8   host_location                                 13300 non-null  object
# ...

# %%
#Numeric Columns Stored as Objects
df['bedrooms'] =pd.to_numeric(df['bedrooms'], errors='coerce')
df['beds'] =pd.to_numeric(df['beds'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   description                                   17703 non-null  object
#  4   neighborhood_overview                         8410 non-null   object
#  5   host_id                                       18017 non-null  int64
#  6   host_name                                     18009 non-null  object
#  7   host_since                                    6763 non-null   datetime64[ns]
#  8   host_location                                 13300 non-null  object
# ...

# %%
#Detect Wrong Type
df.select_dtypes(include='object').head()
# Out:
#         source                               name  \
# 0  city scrape           Tree Topz by Beach Stays
# 1  city scrape  Fabulous location, fabulous place
# 2  city scrape        LUXURY BEACHFRONT APARTMENT
# 3  city scrape                 Coogee Beach House
# 4  city scrape               An Oasis in the City
#
#                                          description  \
# 0  Treetopz is a secluded haven perched high abov...
# 1  Fresh and fun Hollywood Regency apartment in t...
# 2  My warm, comfortable two bedroom apartment lie...
# 3  Coogee Beach House is contemporary residence i...
# 4  Very central to the city which can be reached ...
#
#                                neighborhood_overview    host_name  \
# 0  Pittwater on the Northern Beaches of Sydney is...  Beach Stays
# 1  The cafes and bars are fantastic. Also some br...       Trevor
# 2  I love being so close to nature. Sometimes I s...       Janice
# 3  In this house you are between Clovelly and Coo...      Kristin
# ...

# %%
#Columns that Should Became Numeric
df['host_response_rate'] = pd.to_numeric(
    df['host_response_rate'].astype(str).str.replace('%',''),
    errors='coerce'
)

df['host_acceptance_rate'] = pd.to_numeric(
    df['host_acceptance_rate'].astype(str).str.replace('%',''),
    errors='coerce'
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   description                                   17703 non-null  object
#  4   neighborhood_overview                         8410 non-null   object
#  5   host_id                                       18017 non-null  int64
#  6   host_name                                     18009 non-null  object
#  7   host_since                                    6763 non-null   datetime64[ns]
#  8   host_location                                 13300 non-null  object
# ...

# %%
#Convert Date Columns
df['calendar_last_scraped'] = pd.to_datetime(df['calendar_last_scraped'])
df['first_review'] = pd.to_datetime(df['first_review'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   description                                   17703 non-null  object
#  4   neighborhood_overview                         8410 non-null   object
#  5   host_id                                       18017 non-null  int64
#  6   host_name                                     18009 non-null  object
#  7   host_since                                    6763 non-null   datetime64[ns]
#  8   host_location                                 13300 non-null  object
# ...

# %%
#Convert Boolean Columns
df['instant_bookable'] = df['instant_bookable'].map({'t':True,'f':False})
df['has_availability'] = df['has_availability'].map({'t':True,'f':False})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   description                                   17703 non-null  object
#  4   neighborhood_overview                         8410 non-null   object
#  5   host_id                                       18017 non-null  int64
#  6   host_name                                     18009 non-null  object
#  7   host_since                                    6763 non-null   datetime64[ns]
#  8   host_location                                 13300 non-null  object
# ...

# %%
#Clean Bathroom Column
df['bathrooms'] = df['bathrooms_text'].str.extract('(\d+\.?\d*)').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   description                                   17703 non-null  object
#  4   neighborhood_overview                         8410 non-null   object
#  5   host_id                                       18017 non-null  int64
#  6   host_name                                     18009 non-null  object
#  7   host_since                                    6763 non-null   datetime64[ns]
#  8   host_location                                 13300 non-null  object
# ...

# %%
#Drop Old Columns
df.drop(columns=['bathrooms_text'], inplace=True)

# %%
#Drop Long Columns
df.drop(columns=['description','neighborhood_overview','host_about'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18017 entries, 0 to 18016
# Data columns (total 70 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18017 non-null  float64
#  1   source                                        18017 non-null  object
#  2   name                                          18017 non-null  object
#  3   host_id                                       18017 non-null  int64
#  4   host_name                                     18009 non-null  object
#  5   host_since                                    6763 non-null   datetime64[ns]
#  6   host_location                                 13300 non-null  object
#  7   host_response_time                            15018 non-null  object
#  8   host_response_rate                            15018 non-null  float64
# ...

# %%
#Check Missing Values
df.isnull().sum().sort_values(ascending=False)
# Out:
# neighbourhood_group_cleansed    18017
# calendar_updated                18017
# host_neighbourhood              13103
# host_since                      11254
# neighbourhood                    9607
#                                 ...
# maximum_nights_avg_ntm              0
# availability_30                     0
# availability_60                     0
# availability_90                     0
# maximum_minimum_nights              0
# Length: 70, dtype: int64

# %%
#Drop Column
df.drop(columns=[
'neighbourhood_group_cleansed',
'calendar_updated',
'host_neighbourhood'
], inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'source', 'name', 'host_id', 'host_name', 'host_since',
#        'host_location', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
# ...

# %%
#Handle Missing Values
df['neighbourhood'].fillna('Unknown', inplace=True)
df['host_location'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16464\2653276843.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['neighbourhood'].fillna('Unknown', inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16464\2653276843.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#Handle Missing Numeric Values
df['reviews_per_month'].fillna(df['reviews_per_month'].median(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16464\2764524082.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reviews_per_month'].fillna(df['reviews_per_month'].median(), inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# host_since                11254
# review_scores_value        3037
# review_scores_location     3037
# review_scores_accuracy     3037
# review_scores_checkin      3037
#                           ...
# minimum_nights_avg_ntm        0
# maximum_nights_avg_ntm        0
# availability_30               0
# availability_60               0
# reviews_per_month             0
# Length: 67, dtype: int64

# %%
df['price'].describe()
# Out:
# count    15544.000000
# mean       371.576300
# std        655.741298
# min         16.000000
# 25%        152.000000
# 50%        234.000000
# 75%        373.000000
# max      29199.000000
# Name: price, dtype: float64

# %%
#Clean Price Columns
df['price'] = pd.to_numeric(
    df['price'].astype(str).str.replace('$','').str.replace(',',''),
    errors='coerce'
)
df['price'].describe()
# Out:
# count    15544.000000
# mean       371.576300
# std        655.741298
# min         16.000000
# 25%        152.000000
# 50%        234.000000
# 75%        373.000000
# max      29199.000000
# Name: price, dtype: float64

# %%
df = df[df['price'] > 0]
df['price'].describe()
# Out:
# count    15544.000000
# mean       371.576300
# std        655.741298
# min         16.000000
# 25%        152.000000
# 50%        234.000000
# 75%        373.000000
# max      29199.000000
# Name: price, dtype: float64

# %%
#Remove Outlier(IQR Method)
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['price'] >= lower) & (df['price'] <= upper)]
df['price'].describe()
# Out:
# count    14121.000000
# mean       246.783160
# std        140.275286
# min         16.000000
# 25%        146.000000
# 50%        218.000000
# 75%        320.000000
# max        704.000000
# Name: price, dtype: float64

# %%
#Price Per Person
df['price_per_person'] = df['price'] / df['accommodates']

# %%
#Host Experiences
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')
df['host_since'].dtype  #Verify Datatype
# Out:
# dtype('<M8[ns]')

# %%
#Create Host Experience Column
df['host_experience_years'] = 2025 - df['host_since'].dt.year
df['host_experience_years'] = df['host_experience_years'].fillna(0).astype(int) #Change Experience Datatype
df[['host_since','host_experience_years']].head()
# Out:
#   host_since  host_experience_years
# 0 2014-11-12                     11
# 1        NaT                      0
# 2        NaT                      0
# 4        NaT                      0
# 5 2009-03-12                     16

# %%
#Automatically Update Every Year
df['host_experience_years'] = pd.Timestamp.now().year - df['host_since'].dt.year

# %%
#Create Price Column
df['price_category'] = pd.cut(
    df['price'],
    bins=[0,100,250,400,600],
    labels=['Budget','Standard','Premium','Luxury']
)
df[['price','price_category']].head()
# Out:
#    price price_category
# 0  657.0            NaN
# 1  210.0       Standard
# 2  157.0       Standard
# 4   65.0         Budget
# 5  115.0       Standard

# %%
df['price_category'].value_counts()
# Out:
# price_category
# Standard    6577
# Premium     3684
# Budget      1891
# Luxury      1622
# Name: count, dtype: int64

# %%
#Review Score Category
df['rating_category'] = pd.cut(
    df['review_scores_rating'],
    bins=[0,60,80,90,100],
    labels=['Poor','Average','Good','Excellent']
)

# %%
df['first_review'] = pd.to_datetime(df['first_review'], errors='coerce')
df['first_review'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Listing Age
df['listing_age'] = 2025 - df['first_review'].dt.year
df['listing_age'] = df['listing_age'].fillna(0).astype(int) #Change listing Datatype
df['listing_age'] = pd.Timestamp.now().year - df['first_review'].dt.year  #Automatically Update Every year 
df[['first_review','listing_age']].head()
# Out:
#   first_review  listing_age
# 0   2014-09-30         12.0
# 1   2016-07-24         10.0
# 2   2015-06-29         11.0
# 4   2009-12-05         17.0
# 5   2012-02-23         14.0

# %%
df[['first_review','listing_age']].head()
# Out:
#   first_review  listing_age
# 0   2014-09-30         12.0
# 1   2016-07-24         10.0
# 2   2015-06-29         11.0
# 4   2009-12-05         17.0
# 5   2012-02-23         14.0

# %%
#Review File Cleaning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_reviews =pd.read_csv(r"C:\Users\Dell\Desktop\Australia/reviews.csv")
df_reviews.head()
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642151 entries, 0 to 642150
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     642151 non-null  int64
#  1   id             642151 non-null  int64
#  2   date           642151 non-null  object
#  3   reviewer_id    642151 non-null  int64
#  4   reviewer_name  642151 non-null  object
#  5   comments       642060 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 29.4+ MB

# %%
#Check Null Values
df_reviews.isnull().sum()
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         91
# dtype: int64

# %%
#Fill Null Value
df_reviews['comments'] = df_reviews['comments'].fillna("No Review")

# %%
#Convert Date Column
df_reviews['date'] = pd.to_datetime(df_reviews['date'])
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642151 entries, 0 to 642150
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     642151 non-null  int64
#  1   id             642151 non-null  int64
#  2   date           642151 non-null  datetime64[ns]
#  3   reviewer_id    642151 non-null  int64
#  4   reviewer_name  642151 non-null  object
#  5   comments       642151 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 29.4+ MB

# %%
#Calendar File Cleaning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_calendar =pd.read_csv(r"C:\Users\Dell\Desktop\Australia\calendar.csv")
df_calendar.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16464\761260121.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_calendar =pd.read_csv(r"C:\Users\Dell\Desktop\Australia\calendar.csv")
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0       11156  03-03-2025         t  $65.00            NaN              90
# 1       11156  04-03-2025         f  $65.00            NaN              90
# 2       11156  05-03-2025         t  $65.00            NaN              90
# 3       11156  06-03-2025         t  $65.00            NaN              90
# 4       11156  07-03-2025         t  $65.00            NaN              90
#
#    maximum_nights
# 0             180
# 1             180
# 2             180
# 3             180
# 4             180

# %%
df_calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      1048575 non-null  int64
#  1   date            1048575 non-null  object
#  2   available       1048575 non-null  object
#  3   price           1048575 non-null  object
#  4   adjusted_price  1095 non-null     object
#  5   minimum_nights  1048575 non-null  int64
#  6   maximum_nights  1048575 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 56.0+ MB

# %%
df_calendar.isnull().sum()
# Out:
# listing_id              0
# date                    0
# available               0
# price                   0
# adjusted_price    1047480
# minimum_nights          0
# maximum_nights          0
# dtype: int64

# %%
df_calendar.drop(columns=['adjusted_price'], inplace=True)

# %%
df_calendar.columns
# Out:
# Index(['listing_id', 'date', 'available', 'price', 'minimum_nights',
#        'maximum_nights'],
#       dtype='object')

# %%
#Convert Date Column
df_calendar['date'] = pd.to_datetime(df_calendar['date'], dayfirst=True)
df_calendar['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Clean Price Column
df_calendar['price'] = pd.to_numeric(
    df_calendar['price'].astype(str)
    .str.replace('$','')
    .str.replace(',',''),
    errors='coerce'
)
df_calendar['price'].describe()
# Out:
# count    1.048575e+06
# mean     5.167995e+02
# std      9.333349e+03
# min      2.000000e+01
# 25%      1.200000e+02
# 50%      2.000000e+02
# 75%      3.500000e+02
# max      5.000000e+05
# Name: price, dtype: float64

# %%
#Identify and Remove Outliers 
df_calendar[df_calendar['price'] > 2000].head()
df_calendar = df_calendar[df_calendar['price'] < 2000]
df_calendar['price'].describe()
# Out:
# count    1.029960e+06
# mean     2.965081e+02
# std      2.907935e+02
# min      2.000000e+01
# 25%      1.200000e+02
# 50%      1.950000e+02
# 75%      3.500000e+02
# max      1.999000e+03
# Name: price, dtype: float64

# %%
df_calendar['available'].unique()
# Out:
# array(['t', 'f'], dtype=object)

# %%
df_calendar['available'] = df_calendar['available'].map({'t': True, 'f': False})

# %%
df_calendar.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
#Calculate Listing Metrics
calendar_summary = df_calendar.groupby('listing_id').agg({
    'price':'mean',
    'available':'sum',
    'date':'count'
}).reset_index()

# %%
#Rename Column
calendar_summary.columns = [
    'listing_id',
    'avg_price',
    'available_days',
    'total_days'
]

# %%
#Calculate Availability Rate
calendar_summary['availability_rate'] = (
    calendar_summary['available_days'] /
    calendar_summary['total_days']
)

# %%
#Calculate Booking Rate
calendar_summary['booking_rate'] = 1 - calendar_summary['availability_rate']

# %%
calendar_summary.head()
# Out:
#    listing_id  avg_price  available_days  total_days  availability_rate  \
# 0       11156       65.0             364         365           0.997260
# 1       15253       99.0             216         365           0.591781
# 2       44545      130.0               5         365           0.013699
# 3       58506      200.0             182         365           0.498630
# 4       68999      115.0             254         365           0.695890
#
#    booking_rate
# 0      0.002740
# 1      0.408219
# 2      0.986301
# 3      0.501370
# 4      0.304110

# %%
#Translate2 File Cleaning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_translate2 =pd.read_csv(r"C:\Users\Dell\Desktop\Australia\translate 2.csv")
df_translate2.head()
# Out:
#    listing_id                   id        date  reviewer_id reviewer_name  \
# 0     1054789  1137290000000000000  17-04-2024    357370888            渡辺
# 1     1054789  1143110000000000000  26-04-2024    567632364          Hung
# 2     1054789  1160480000000000000  19-05-2024    500074832            창훈
# 3     1054789  1214870000000000000  03-08-2024    492289313         Nghia
# 4     1054789  1244590000000000000  13-09-2024    559549218       Jaehyun
#
#                                             English
# 0      It was nice that it was close to the station.
# 1                      I had a memorable experience.
# 2  The accommodation is very accessible from the ...
# 3                                Will comeback again
# 4           The host is very friendly and respectful

# %%
df_translate2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519533 entries, 0 to 519532
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     519533 non-null  int64
#  1   id             519533 non-null  int64
#  2   date           519533 non-null  object
#  3   reviewer_id    519533 non-null  int64
#  4   reviewer_name  519533 non-null  object
#  5   English        519531 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 23.8+ MB

# %%
df_translate2.shape
# Out:
# (519533, 6)

# %%
#Check Missing Value
df_translate2.isnull().sum().sort_values(ascending=False)
# Out:
# English          2
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# dtype: int64

# %%
#Convert Date Column
df_translate2['date'] = pd.to_datetime(df_translate2['date']) 
df_translate2['date'].dtype
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16464\3035098097.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_translate2['date'] = pd.to_datetime(df_translate2['date'])
# dtype('<M8[ns]')

# %%
#Handle Missing English Text
df_translate2[df_translate2['English'].isnull()] 
df_translate2['English'] = df_translate2['English'].fillna('')

# %%
df_translate2.columns = df_translate2.columns.str.strip()
df_translate2.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'English'], dtype='object')

# %%
#Drop Duplicate
df_translate2.duplicated().sum()
df_translate2.drop_duplicates(inplace=True)

# %%
#Final Check
df_translate2.isnull().sum()

# %%
#Load the JSON File
import json

with open(r"C:\Users\Dell\Desktop\Australia\neighbourhoods.geojson") as f:
    neighbourhood_data = json.load(f)

# %%
neighbourhood_data.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
#Check File Features
neighbourhood_data['features'][0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[151.296141, -33.572912],
#      [151.296188, -33.572913],
#      [151.296234, -33.572912],
#      [151.296296, -33.572904],
#      [151.296357, -33.57289],
#      [151.296418, -33.572872],
#      [151.296479, -33.572854],
#      [151.296541, -33.572839],
#      [151.296618, -33.572828],
#      [151.296697, -33.572822],
#      [151.296775, -33.572814],
#      [151.296849, -33.5728],
#      [151.296916, -33.572772],
#      [151.296971, -33.572726],
#      [151.297017, -33.572666],
#      [151.29706, -33.572599],
#      [151.297105, -33.572535],
#      [151.297158, -33.572483],
#      [151.297281, -33.572418],
#      [151.297428, -33.572382],
#      [151.297588, -33.572365],
#      [151.297752, -33.57236],
#      [151.297908, -33.57236],
#      [151.298129, -33.57237],
#      [151.298353, -33.572402],
#      [151.298575, -33.572454],
#      [151.29879, -33.572524],
#      [151.298994, -33.572611],
# ...

# %%
#Number of Neighbourhood
len(neighbourhood_data['features'])
# Out:
# 38

# %%
#Merge File
df_final = df.merge(calendar_summary, on='listing_id', how='left')
df_final.shape
# Out:
# (14121, 77)

# %%
#Rename Column Name in Listing File
df.rename(columns={'id':'listing_id'}, inplace=True) 
df.columns
# Out:
# Index(['listing_id', 'source', 'name', 'host_id', 'host_name', 'host_since',
#        'host_location', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights',
#        'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
# ...

# %%
df_final.head()
# Out:
#    listing_id       source                                               name  \
# 0   1051911.0  city scrape                           Tree Topz by Beach Stays
# 1   1100380.0  city scrape                  Fabulous location, fabulous place
# 2   1125557.0  city scrape                        LUXURY BEACHFRONT APARTMENT
# 3     11156.0  city scrape                               An Oasis in the City
# 4     15253.0  city scrape  Unique Designer Rooftop Apartment in City Loca...
#
#     host_id    host_name host_since           host_location  \
# 0  24721535  Beach Stays 2014-11-12                 Unknown
# 1   6044810       Trevor        NaT  Surry Hills, Australia
# 2   8402583       Janice        NaT     Cronulla, Australia
# 3     40855      Colleen        NaT  Potts Point, Australia
# 4     59850        Morag 2009-03-12       Sydney, Australia
#
#    host_response_time  host_response_rate  host_acceptance_rate  ...  \
# ...

# %%
#Merge Review File
review_summary = df_translate2.groupby('listing_id').size().reset_index(name='total_reviews')

# %%
df_final = df_final.merge(review_summary, on='listing_id', how='left')
df_final['total_reviews'] = df_final['total_reviews'].fillna(0)

# %%
review_summary.head()
review_summary.columns
# Out:
# Index(['listing_id', 'total_reviews'], dtype='object')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14121 entries, 0 to 14120
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_id                                    14121 non-null  float64
#  1   source                                        14121 non-null  object
#  2   name                                          14121 non-null  object
#  3   host_id                                       14121 non-null  int64
#  4   host_name                                     14115 non-null  object
#  5   host_since                                    5287 non-null   datetime64[ns]
#  6   host_location                                 14121 non-null  object
#  7   host_response_time                            12184 non-null  object
#  8   host_response_rate                            12184 non-null  float64
# ...

# %%
df_final['avg_price'] = df_final['avg_price'].fillna(df_final['price'])
df_final['available_days'] = df_final['available_days'].fillna(0)
df_final['availability_rate'] = df_final['availability_rate'].fillna(0)
df_final['booking_rate'] = df_final['booking_rate'].fillna(0)

# %%
df_final['price'] = (
    df_final['price']
    .astype(str)
    .str.replace('$','')
    .str.replace(',','')
    .astype(float)
)

# %%
df_final['price'].dtype
# Out:
# dtype('float64')

# %%
date_cols = ['first_review','last_review','host_since','calendar_last_scraped']

for col in date_cols:
    df_final[col] = pd.to_datetime(df_final[col], errors='coerce')

# %%
df_final.columns = df_final.columns.str.strip()

# %%
#Remove Useless Columns
df_final.drop(
    columns=['calendar_updated','neighbourhood_group_cleansed'],
    inplace=True,
    errors='ignore'
)

# %%
#Final Check
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14121 entries, 0 to 14120
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_id                                    14121 non-null  float64
#  1   source                                        14121 non-null  object
#  2   name                                          14121 non-null  object
#  3   host_id                                       14121 non-null  int64
#  4   host_name                                     14115 non-null  object
#  5   host_since                                    5287 non-null   datetime64[ns]
#  6   host_location                                 14121 non-null  object
#  7   host_response_time                            12184 non-null  object
#  8   host_response_rate                            12184 non-null  float64
# ...

# %%
text_cols = ['description','neighbourhood_overview','host_about','host_location']

for col in text_cols:
    if col in df_final.columns:
        df_final[col] = df_final[col].fillna('Not Available')

# %%
df_final['avg_price'] = pd.to_numeric(df_final['avg_price'], errors='coerce') 
df_final['avg_price'].dtype
# Out:
# dtype('float64')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14121 entries, 0 to 14120
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_id                                    14121 non-null  float64
#  1   source                                        14121 non-null  object
#  2   name                                          14121 non-null  object
#  3   host_id                                       14121 non-null  int64
#  4   host_name                                     14115 non-null  object
#  5   host_since                                    5287 non-null   datetime64[ns]
#  6   host_location                                 14121 non-null  object
#  7   host_response_time                            12184 non-null  object
#  8   host_response_rate                            12184 non-null  float64
# ...

# %%
df_final.shape
# Out:
# (14121, 78)

# %%
df_final.describe()
# Out:
#          listing_id       host_id                     host_since  \
# count  1.412100e+04  1.412100e+04                           5287
# mean   7.125940e+17  2.110323e+08  2018-02-06 03:03:50.830338560
# min    1.115600e+04  3.558200e+04            2009-02-09 00:00:00
# 25%    4.198497e+07  3.447381e+07            2015-04-10 00:00:00
# 50%    9.030000e+17  1.390962e+08            2017-07-01 00:00:00
# 75%    1.200000e+18  3.505126e+08            2020-10-06 00:00:00
# max    1.370000e+18  6.818117e+08            2025-12-02 00:00:00
# std    5.384928e+17  2.016312e+08                            NaN
#
#        host_response_rate  host_acceptance_rate  host_listings_count  \
# count        12184.000000          12510.000000         14115.000000
# mean            95.772406             86.820304            32.584485
# min              0.000000              0.000000             0.000000
# 25%            100.000000             86.000000             1.000000
# ...

# %%
df_final.describe(include='object')
# Out:
#              source                              name host_name  \
# count         14121                             14121     14115
# unique            1                             13726      3343
# top     city scrape  Modern Elegance of Mascot Living       Ken
# freq          14121                                17       240
#
#             host_location host_response_time host_is_superhost  \
# count               14121              12184             13518
# unique                677                  4                 2
# top     Sydney, Australia     within an hour                 f
# freq                 4835               9373              9127
#
#                                        host_thumbnail_url  \
# count                                               14115
# unique                                               6944
# top     https://a0.muscache.com/defaults/user_pic-50x5...
# freq                                                  449
#
# ...

# %%
#Check Unique Listing
df_final['listing_id'].nunique()
# Out:
# 5244

# %%
#Listing Dataset
df_listing = df_final.drop_duplicates(subset='listing_id')

# %%
df_listing.shape
# Out:
# (5244, 78)

# %%
#Room Type Distributions
df_listing['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    3843
# Private room       1319
# Hotel room           79
# Shared room           3
# Name: count, dtype: int64

# %%
#Average Price
df_listing['price'].describe()
# Out:
# count    5244.000000
# mean      239.164950
# std       144.267635
# min        17.000000
# 25%       134.000000
# 50%       205.000000
# 75%       315.000000
# max       701.000000
# Name: price, dtype: float64

# %%
#Top Neighborhood
df_listing.groupby('neighbourhood_cleansed')['price'].mean().sort_values(ascending=False).head(10)
# Out:
# neighbourhood_cleansed
# Manly               339.369048
# Pittwater           298.991489
# Woollahra           296.343949
# Waverley            295.205882
# Sydney              270.202390
# Warringah           267.342960
# Mosman              264.045455
# Randwick            252.553892
# Sutherland Shire    243.713376
# North Sydney        236.841410
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['price'], bins=50)
plt.title("Price Distribution")
plt.show()

# %%
df['property_type'].value_counts().head(10).plot(kind='bar')
plt.title("Top Property Types")
plt.show()

# %%
sns.countplot(data=df, x='room_type')
plt.title("Room Type Distribution")
plt.show()

# %%
sns.boxplot(data=df, x='room_type', y='price')
plt.title("Price by Room Type")
plt.show()

# %%
top_neigh = df['neighbourhood_cleansed'].value_counts().head(10)

top_neigh.plot(kind='bar')
plt.title("Top Neighborhoods by Listings")
plt.show()

# %%
print('Relationship between popularity and rating.')
sns.scatterplot(
    data=df,
    x='number_of_reviews',
    y='review_scores_rating'
)
plt.show()
# Out:
# Relationship between popularity and rating.

# %%
sns.countplot(x='host_is_superhost', data=df)
plt.title("Superhost Distribution")
plt.show()

# %%
sns.histplot(df['availability_365'])
plt.title("Availability Days per Year")
plt.show()

# %%
sns.scatterplot(
    data=df,
    x='price',
    y='estimated_revenue_l365d'
)
# Out:
# <Axes: xlabel='price', ylabel='estimated_revenue_l365d'>

# %%
rating_cols = [
'review_scores_rating',
'review_scores_cleanliness',
'review_scores_location',
'review_scores_value'
]

df[rating_cols].boxplot()
plt.show()

# %%
# Export final cleaned dataset
df.to_csv("airbnb_final_dataset.csv", index=False)
